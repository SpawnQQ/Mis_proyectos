# %%
options =["piedra", "papel", "tijeras"]

def search_winner(p1, p2):
	if p1 == p2:
		result = 0
	elif p1 == "piedra" and p2 == "tijeras":
		result = 1
	elif p1 == "piedra" and p2 == "papel":
		result = 2
	elif p1 == "papel" and p2 == "tijeras":
		result = 2
	elif p1 == "papel" and p2 == "piedra":
		result = 1
	elif p1 == "tijeras" and p2 == "piedra":
		result = 2
	elif p1 == "tijeras" and p2 == "papel":
		result = 1

	return result

from random import choice

def get_choice():
	return choice(options)

for i in range(10):
	player1 = get_choice()
	player2 = get_choice()
	print("player1: %s player2: %s Winner: %s " %(player1,player2, search_winner(player1, player2)))
# Out:
# player1: piedra player2: papel Winner: 2
# player1: tijeras player2: piedra Winner: 2
# player1: papel player2: papel Winner: 0
# player1: papel player2: tijeras Winner: 2
# player1: piedra player2: papel Winner: 2
# player1: piedra player2: piedra Winner: 0
# player1: papel player2: papel Winner: 0
# player1: piedra player2: papel Winner: 2
# player1: piedra player2: tijeras Winner: 1
# player1: tijeras player2: piedra Winner: 2

# %%
def str_to_list(option):
	if option == "piedra":
		res = [1,0,0]
	if option == "papel":
		res = [0,1,0]
	if option == "tijeras":
		res = [0,0,1]

	return res

data_x1 = list(map(str_to_list, ["piedra", "papel", "tijeras"]))
data_x2 = list(map(str_to_list, ["papel", "tijeras", "papel"]))

print(data_x1)
print(data_x2)
# Out:
# [[1, 0, 0], [0, 1, 0], [0, 0, 1]]
# [[0, 1, 0], [0, 0, 1], [0, 1, 0]]

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(verbose=False, warm_start=True)

model = clf.fit([data_x1[0]], [data_x2[0]])
print(model)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)
# /home/spawnqq/.local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
def play_and_learn(iters=10, debug=False):
	score = {"win": 0, "loose": 0}
	
	data_x1 = []
	data_x2 = []
	
	for i in range(iters):
		player1 = get_choice()
		
		predict = model.predict_proba([str_to_list(player1)])[0]
		
		if predict[0] >= 0.95:
			player2 = options[0]
		elif predict[1] >= 0.95:
			player2 = options[1]
		elif predict[2] >= 0.95:
			player2 = options[2]
		else:
			player2 = get_choice()

		if debug==True:
			print("Player1: %s Player2 (modelo): %s --> %s" % (player1, predict, player2))

		winner = search_winner(player1, player2)
		if debug==True:
			print("Comprobamos: p1 VS p2: %s" % winner)

		if winner==2:
			data_x1.append(str_to_list(player1))
			data_x2.append(str_to_list(player2))

			score["win"]+=1
		else:
			score["loose"]+=1

	return score, data_x1, data_x2

# %%
score, data_x1, data_x2 = play_and_learn(1, debug=True)
print(data_x1)
print(data_x2)
print("Score: %s %s %%" % (score, (score["win"]*100/(score["win"]+score["loose"]))))
if len(data_x1):
	model = model.partial_fit(data_x1, data_x2)

i = 0
historic_pct = []
while True:
	i+=1
	score, data_x1, data_x2 = play_and_learn(1000, debug=False)
	pct = (score["win"]*100/(score["win"]+score["loose"]))
	historic_pct.append(pct)
	print("Iter: %s - score: %s %s %%" % (i, score, pct))

	if len(data_x1):
		model = model.partial_fit(data_x1, data_x2)

	if sum(historic_pct[-9:])==900:
		break
# Out:
# Player1: piedra Player2 (modelo): [0.02550158 0.97108195 0.02181049] --> papel
# Comprobamos: p1 VS p2: 2
# [[1, 0, 0]]
# [[0, 1, 0]]
# Score: {'win': 1, 'loose': 0} 100.0 %
# Iter: 1 - score: {'win': 552, 'loose': 448} 55.2 %
# Iter: 2 - score: {'win': 552, 'loose': 448} 55.2 %
# Iter: 3 - score: {'win': 556, 'loose': 444} 55.6 %
# Iter: 4 - score: {'win': 556, 'loose': 444} 55.6 %
# Iter: 5 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 6 - score: {'win': 560, 'loose': 440} 56.0 %
# Iter: 7 - score: {'win': 544, 'loose': 456} 54.4 %
# Iter: 8 - score: {'win': 541, 'loose': 459} 54.1 %
# Iter: 9 - score: {'win': 552, 'loose': 448} 55.2 %
# Iter: 10 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 11 - score: {'win': 345, 'loose': 655} 34.5 %
# Iter: 12 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 13 - score: {'win': 355, 'loose': 645} 35.5 %
# Iter: 14 - score: {'win': 323, 'loose': 677} 32.3 %
# Iter: 15 - score: {'win': 318, 'loose': 682} 31.8 %
# Iter: 16 - score: {'win': 347, 'loose': 653} 34.7 %
# Iter: 17 - score: {'win': 345, 'loose': 655} 34.5 %
# Iter: 18 - score: {'win': 365, 'loose': 635} 36.5 %
# Iter: 19 - score: {'win': 336, 'loose': 664} 33.6 %
# Iter: 20 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 21 - score: {'win': 311, 'loose': 689} 31.1 %
# Iter: 22 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 23 - score: {'win': 354, 'loose': 646} 35.4 %
# Iter: 24 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 25 - score: {'win': 344, 'loose': 656} 34.4 %
# Iter: 26 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 27 - score: {'win': 349, 'loose': 651} 34.9 %
# Iter: 28 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 29 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 30 - score: {'win': 350, 'loose': 650} 35.0 %
# Iter: 31 - score: {'win': 361, 'loose': 639} 36.1 %
# Iter: 32 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 33 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 34 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 35 - score: {'win': 358, 'loose': 642} 35.8 %
# Iter: 36 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 37 - score: {'win': 348, 'loose': 652} 34.8 %
# Iter: 38 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 39 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 40 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 41 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 42 - score: {'win': 342, 'loose': 658} 34.2 %
# Iter: 43 - score: {'win': 352, 'loose': 648} 35.2 %
# Iter: 44 - score: {'win': 358, 'loose': 642} 35.8 %
# Iter: 45 - score: {'win': 312, 'loose': 688} 31.2 %
# Iter: 46 - score: {'win': 365, 'loose': 635} 36.5 %
# Iter: 47 - score: {'win': 339, 'loose': 661} 33.9 %
# Iter: 48 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 49 - score: {'win': 300, 'loose': 700} 30.0 %
# Iter: 50 - score: {'win': 298, 'loose': 702} 29.8 %
# Iter: 51 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 52 - score: {'win': 346, 'loose': 654} 34.6 %
# Iter: 53 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 54 - score: {'win': 310, 'loose': 690} 31.0 %
# Iter: 55 - score: {'win': 362, 'loose': 638} 36.2 %
# Iter: 56 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 57 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 58 - score: {'win': 348, 'loose': 652} 34.8 %
# Iter: 59 - score: {'win': 333, 'loose': 667} 33.3 %
# Iter: 60 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 61 - score: {'win': 317, 'loose': 683} 31.7 %
# Iter: 62 - score: {'win': 355, 'loose': 645} 35.5 %
# Iter: 63 - score: {'win': 327, 'loose': 673} 32.7 %
# Iter: 64 - score: {'win': 333, 'loose': 667} 33.3 %
# Iter: 65 - score: {'win': 318, 'loose': 682} 31.8 %
# Iter: 66 - score: {'win': 310, 'loose': 690} 31.0 %
# Iter: 67 - score: {'win': 309, 'loose': 691} 30.9 %
# Iter: 68 - score: {'win': 338, 'loose': 662} 33.8 %
# Iter: 69 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 70 - score: {'win': 336, 'loose': 664} 33.6 %
# Iter: 71 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 72 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 73 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 74 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 75 - score: {'win': 300, 'loose': 700} 30.0 %
# Iter: 76 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 77 - score: {'win': 318, 'loose': 682} 31.8 %
# Iter: 78 - score: {'win': 363, 'loose': 637} 36.3 %
# Iter: 79 - score: {'win': 315, 'loose': 685} 31.5 %
# Iter: 80 - score: {'win': 309, 'loose': 691} 30.9 %
# Iter: 81 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 82 - score: {'win': 308, 'loose': 692} 30.8 %
# Iter: 83 - score: {'win': 352, 'loose': 648} 35.2 %
# Iter: 84 - score: {'win': 352, 'loose': 648} 35.2 %
# Iter: 85 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 86 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 87 - score: {'win': 323, 'loose': 677} 32.3 %
# Iter: 88 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 89 - score: {'win': 309, 'loose': 691} 30.9 %
# Iter: 90 - score: {'win': 314, 'loose': 686} 31.4 %
# Iter: 91 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 92 - score: {'win': 326, 'loose': 674} 32.6 %
# Iter: 93 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 94 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 95 - score: {'win': 316, 'loose': 684} 31.6 %
# Iter: 96 - score: {'win': 564, 'loose': 436} 56.4 %
# Iter: 97 - score: {'win': 580, 'loose': 420} 58.0 %
# Iter: 98 - score: {'win': 550, 'loose': 450} 55.0 %
# Iter: 99 - score: {'win': 538, 'loose': 462} 53.8 %
# Iter: 100 - score: {'win': 547, 'loose': 453} 54.7 %
# Iter: 101 - score: {'win': 574, 'loose': 426} 57.4 %
# Iter: 102 - score: {'win': 537, 'loose': 463} 53.7 %
# Iter: 103 - score: {'win': 557, 'loose': 443} 55.7 %
# Iter: 104 - score: {'win': 532, 'loose': 468} 53.2 %
# Iter: 105 - score: {'win': 571, 'loose': 429} 57.1 %
# Iter: 106 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 107 - score: {'win': 578, 'loose': 422} 57.8 %
# Iter: 108 - score: {'win': 555, 'loose': 445} 55.5 %
# Iter: 109 - score: {'win': 512, 'loose': 488} 51.2 %
# Iter: 110 - score: {'win': 551, 'loose': 449} 55.1 %
# Iter: 111 - score: {'win': 568, 'loose': 432} 56.8 %
# Iter: 112 - score: {'win': 570, 'loose': 430} 57.0 %
# Iter: 113 - score: {'win': 581, 'loose': 419} 58.1 %
# Iter: 114 - score: {'win': 575, 'loose': 425} 57.5 %
# Iter: 115 - score: {'win': 540, 'loose': 460} 54.0 %
# Iter: 116 - score: {'win': 538, 'loose': 462} 53.8 %
# Iter: 117 - score: {'win': 547, 'loose': 453} 54.7 %
# Iter: 118 - score: {'win': 554, 'loose': 446} 55.4 %
# Iter: 119 - score: {'win': 544, 'loose': 456} 54.4 %
# Iter: 120 - score: {'win': 571, 'loose': 429} 57.1 %
# Iter: 121 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 122 - score: {'win': 557, 'loose': 443} 55.7 %
# Iter: 123 - score: {'win': 546, 'loose': 454} 54.6 %
# Iter: 124 - score: {'win': 549, 'loose': 451} 54.9 %
# Iter: 125 - score: {'win': 549, 'loose': 451} 54.9 %
# Iter: 126 - score: {'win': 546, 'loose': 454} 54.6 %
# Iter: 127 - score: {'win': 561, 'loose': 439} 56.1 %
# Iter: 128 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 129 - score: {'win': 546, 'loose': 454} 54.6 %
# Iter: 130 - score: {'win': 569, 'loose': 431} 56.9 %
# Iter: 131 - score: {'win': 555, 'loose': 445} 55.5 %
# Iter: 132 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 133 - score: {'win': 550, 'loose': 450} 55.0 %
# Iter: 134 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 135 - score: {'win': 543, 'loose': 457} 54.3 %
# Iter: 136 - score: {'win': 559, 'loose': 441} 55.9 %
# Iter: 137 - score: {'win': 540, 'loose': 460} 54.0 %
# Iter: 138 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 139 - score: {'win': 528, 'loose': 472} 52.8 %
# Iter: 140 - score: {'win': 547, 'loose': 453} 54.7 %
# Iter: 141 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 142 - score: {'win': 536, 'loose': 464} 53.6 %
# Iter: 143 - score: {'win': 536, 'loose': 464} 53.6 %
# Iter: 144 - score: {'win': 534, 'loose': 466} 53.4 %
# Iter: 145 - score: {'win': 538, 'loose': 462} 53.8 %
# Iter: 146 - score: {'win': 584, 'loose': 416} 58.4 %
# Iter: 147 - score: {'win': 556, 'loose': 444} 55.6 %
# Iter: 148 - score: {'win': 538, 'loose': 462} 53.8 %
# Iter: 149 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 150 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 151 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 152 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 153 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 154 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 155 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 156 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 157 - score: {'win': 1000, 'loose': 0} 100.0 %

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15, 8), dpi=70)
plt.title("Porcentaje de aprendizaje en cada iteración")
plt.xlabel("Numero de iteración")
plt.ylabel("Tasa de aprendizaje")

plt.plot(range(len(historic_pct)),historic_pct)

plt.show()
