# %%
options =["piedra", "papel", "tijeras"]

def search_winner(p1, p2):
	if p1 == p2:
		result = 0
	elif p1 == "piedra" and p2 == "tijeras":
		result = 1
	elif p1 == "piedra" and p2 == "papel":
		result = 2
	elif p1 == "papel" and p2 == "tijeras":
		result = 2
	elif p1 == "papel" and p2 == "piedra":
		result = 1
	elif p1 == "tijeras" and p2 == "piedra":
		result = 2
	elif p1 == "tijeras" and p2 == "papel":
		result = 1

	return result

from random import choice

def get_choice():
	return choice(options)

for i in range(10):
	player1 = get_choice()
	player2 = get_choice()
	print("player1: %s player2: %s Winner: %s " %(player1,player2, search_winner(player1, player2)))
# Out:
# player1: papel player2: papel Winner: 0
# player1: tijeras player2: papel Winner: 1
# player1: piedra player2: papel Winner: 2
# player1: tijeras player2: tijeras Winner: 0
# player1: tijeras player2: tijeras Winner: 0
# player1: tijeras player2: papel Winner: 1
# player1: piedra player2: piedra Winner: 0
# player1: piedra player2: tijeras Winner: 1
# player1: papel player2: piedra Winner: 1
# player1: papel player2: papel Winner: 0

# %%
def str_to_list(option):
	if option == "piedra":
		res = [1,0,0]
	if option == "papel":
		res = [0,1,0]
	if option == "tijeras":
		res = [0,0,1]

	return res

data_x1 = list(map(str_to_list, ["piedra", "papel", "tijeras"]))
data_x2 = list(map(str_to_list, ["papel", "tijeras", "papel"]))

print(data_x1)
print(data_x2)
# Out:
# [[1, 0, 0], [0, 1, 0], [0, 0, 1]]
# [[0, 1, 0], [0, 0, 1], [0, 1, 0]]

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(verbose=False, warm_start=True)

model = clf.fit([data_x1[0]], [data_x2[0]])
print(model)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=True)
# /home/spawnqq/.local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
def play_and_learn(iters=10, debug=False):
	score = {"win": 0, "loose": 0}
	
	data_x1 = []
	data_x2 = []
	
	for i in range(iters):
		player1 = get_choice()
		
		predict = model.predict_proba([str_to_list(player1)])[0]
		
		if predict[0] >= 0.95:
			player2 = options[0]
		elif predict[1] >= 0.95:
			player2 = options[1]
		elif predict[2] >= 0.95:
			player2 = options[2]
		else:
			player2 = get_choice()

		if debug==True:
			print("Player1: %s Player2 (modelo): %s --> %s" % (player1, predict, player2))

		winner = search_winner(player1, player2)
		if debug==True:
			print("Comprobamos: p1 VS p2: %s" % winner)

		if winner==2:
			data_x1.append(str_to_list(player1))
			data_x2.append(str_to_list(player2))

			score["win"]+=1
		else:
			score["loose"]+=1

	return score, data_x1, data_x2

# %%
score, data_x1, data_x2 = play_and_learn(1, debug=True)
print(data_x1)
print(data_x2)
print("Score: %s %s %%" % (score, (score["win"]*100/(score["win"]+score["loose"]))))
if len(data_x1):
	model = model.partial_fit(data_x1, data_x2)

i = 0
historic_pct = []
while True:
	i+=1
	score, data_x1, data_x2 = play_and_learn(1000, debug=False)
	pct = (score["win"]*100/(score["win"]+score["loose"]))
	historic_pct.append(pct)
	print("Iter: %s - score: %s %s %%" % (i, score, pct))

	if len(data_x1):
		model = model.partial_fit(data_x1, data_x2)

	if sum(historic_pct[-9:])==900:
		break
# Out:
# Player1: papel Player2 (modelo): [0.13113898 0.855161   0.14785658] --> tijeras
# Comprobamos: p1 VS p2: 2
# [[0, 1, 0]]
# [[0, 0, 1]]
# Score: {'win': 1, 'loose': 0} 100.0 %
# Iter: 1 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 2 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 3 - score: {'win': 550, 'loose': 450} 55.0 %
# Iter: 4 - score: {'win': 515, 'loose': 485} 51.5 %
# Iter: 5 - score: {'win': 545, 'loose': 455} 54.5 %
# Iter: 6 - score: {'win': 546, 'loose': 454} 54.6 %
# Iter: 7 - score: {'win': 550, 'loose': 450} 55.0 %
# Iter: 8 - score: {'win': 545, 'loose': 455} 54.5 %
# Iter: 9 - score: {'win': 544, 'loose': 456} 54.4 %
# Iter: 10 - score: {'win': 336, 'loose': 664} 33.6 %
# Iter: 11 - score: {'win': 342, 'loose': 658} 34.2 %
# Iter: 12 - score: {'win': 318, 'loose': 682} 31.8 %
# Iter: 13 - score: {'win': 323, 'loose': 677} 32.3 %
# Iter: 14 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 15 - score: {'win': 336, 'loose': 664} 33.6 %
# Iter: 16 - score: {'win': 349, 'loose': 651} 34.9 %
# Iter: 17 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 18 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 19 - score: {'win': 313, 'loose': 687} 31.3 %
# Iter: 20 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 21 - score: {'win': 355, 'loose': 645} 35.5 %
# Iter: 22 - score: {'win': 312, 'loose': 688} 31.2 %
# Iter: 23 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 24 - score: {'win': 355, 'loose': 645} 35.5 %
# Iter: 25 - score: {'win': 312, 'loose': 688} 31.2 %
# Iter: 26 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 27 - score: {'win': 341, 'loose': 659} 34.1 %
# Iter: 28 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 29 - score: {'win': 320, 'loose': 680} 32.0 %
# Iter: 30 - score: {'win': 356, 'loose': 644} 35.6 %
# Iter: 31 - score: {'win': 358, 'loose': 642} 35.8 %
# Iter: 32 - score: {'win': 356, 'loose': 644} 35.6 %
# Iter: 33 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 34 - score: {'win': 346, 'loose': 654} 34.6 %
# Iter: 35 - score: {'win': 333, 'loose': 667} 33.3 %
# Iter: 36 - score: {'win': 331, 'loose': 669} 33.1 %
# Iter: 37 - score: {'win': 327, 'loose': 673} 32.7 %
# Iter: 38 - score: {'win': 345, 'loose': 655} 34.5 %
# Iter: 39 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 40 - score: {'win': 335, 'loose': 665} 33.5 %
# Iter: 41 - score: {'win': 326, 'loose': 674} 32.6 %
# Iter: 42 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 43 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 44 - score: {'win': 325, 'loose': 675} 32.5 %
# Iter: 45 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 46 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 47 - score: {'win': 335, 'loose': 665} 33.5 %
# Iter: 48 - score: {'win': 313, 'loose': 687} 31.3 %
# Iter: 49 - score: {'win': 312, 'loose': 688} 31.2 %
# Iter: 50 - score: {'win': 342, 'loose': 658} 34.2 %
# Iter: 51 - score: {'win': 304, 'loose': 696} 30.4 %
# Iter: 52 - score: {'win': 336, 'loose': 664} 33.6 %
# Iter: 53 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 54 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 55 - score: {'win': 322, 'loose': 678} 32.2 %
# Iter: 56 - score: {'win': 329, 'loose': 671} 32.9 %
# Iter: 57 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 58 - score: {'win': 319, 'loose': 681} 31.9 %
# Iter: 59 - score: {'win': 339, 'loose': 661} 33.9 %
# Iter: 60 - score: {'win': 314, 'loose': 686} 31.4 %
# Iter: 61 - score: {'win': 345, 'loose': 655} 34.5 %
# Iter: 62 - score: {'win': 345, 'loose': 655} 34.5 %
# Iter: 63 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 64 - score: {'win': 351, 'loose': 649} 35.1 %
# Iter: 65 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 66 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 67 - score: {'win': 327, 'loose': 673} 32.7 %
# Iter: 68 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 69 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 70 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 71 - score: {'win': 354, 'loose': 646} 35.4 %
# Iter: 72 - score: {'win': 344, 'loose': 656} 34.4 %
# Iter: 73 - score: {'win': 322, 'loose': 678} 32.2 %
# Iter: 74 - score: {'win': 325, 'loose': 675} 32.5 %
# Iter: 75 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 76 - score: {'win': 338, 'loose': 662} 33.8 %
# Iter: 77 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 78 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 79 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 80 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 81 - score: {'win': 314, 'loose': 686} 31.4 %
# Iter: 82 - score: {'win': 352, 'loose': 648} 35.2 %
# Iter: 83 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 84 - score: {'win': 311, 'loose': 689} 31.1 %
# Iter: 85 - score: {'win': 354, 'loose': 646} 35.4 %
# Iter: 86 - score: {'win': 314, 'loose': 686} 31.4 %
# Iter: 87 - score: {'win': 334, 'loose': 666} 33.4 %
# Iter: 88 - score: {'win': 327, 'loose': 673} 32.7 %
# Iter: 89 - score: {'win': 323, 'loose': 677} 32.3 %
# Iter: 90 - score: {'win': 338, 'loose': 662} 33.8 %
# Iter: 91 - score: {'win': 322, 'loose': 678} 32.2 %
# Iter: 92 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 93 - score: {'win': 320, 'loose': 680} 32.0 %
# Iter: 94 - score: {'win': 343, 'loose': 657} 34.3 %
# Iter: 95 - score: {'win': 325, 'loose': 675} 32.5 %
# Iter: 96 - score: {'win': 332, 'loose': 668} 33.2 %
# Iter: 97 - score: {'win': 339, 'loose': 661} 33.9 %
# Iter: 98 - score: {'win': 355, 'loose': 645} 35.5 %
# Iter: 99 - score: {'win': 341, 'loose': 659} 34.1 %
# Iter: 100 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 101 - score: {'win': 335, 'loose': 665} 33.5 %
# Iter: 102 - score: {'win': 339, 'loose': 661} 33.9 %
# Iter: 103 - score: {'win': 318, 'loose': 682} 31.8 %
# Iter: 104 - score: {'win': 304, 'loose': 696} 30.4 %
# Iter: 105 - score: {'win': 324, 'loose': 676} 32.4 %
# Iter: 106 - score: {'win': 325, 'loose': 675} 32.5 %
# Iter: 107 - score: {'win': 321, 'loose': 679} 32.1 %
# Iter: 108 - score: {'win': 349, 'loose': 651} 34.9 %
# Iter: 109 - score: {'win': 330, 'loose': 670} 33.0 %
# Iter: 110 - score: {'win': 328, 'loose': 672} 32.8 %
# Iter: 111 - score: {'win': 340, 'loose': 660} 34.0 %
# Iter: 112 - score: {'win': 326, 'loose': 674} 32.6 %
# Iter: 113 - score: {'win': 312, 'loose': 688} 31.2 %
# Iter: 114 - score: {'win': 344, 'loose': 656} 34.4 %
# Iter: 115 - score: {'win': 317, 'loose': 683} 31.7 %
# Iter: 116 - score: {'win': 542, 'loose': 458} 54.2 %
# Iter: 117 - score: {'win': 558, 'loose': 442} 55.8 %
# Iter: 118 - score: {'win': 550, 'loose': 450} 55.0 %
# Iter: 119 - score: {'win': 547, 'loose': 453} 54.7 %
# Iter: 120 - score: {'win': 573, 'loose': 427} 57.3 %
# Iter: 121 - score: {'win': 561, 'loose': 439} 56.1 %
# Iter: 122 - score: {'win': 561, 'loose': 439} 56.1 %
# Iter: 123 - score: {'win': 540, 'loose': 460} 54.0 %
# Iter: 124 - score: {'win': 559, 'loose': 441} 55.9 %
# Iter: 125 - score: {'win': 530, 'loose': 470} 53.0 %
# Iter: 126 - score: {'win': 540, 'loose': 460} 54.0 %
# Iter: 127 - score: {'win': 548, 'loose': 452} 54.8 %
# Iter: 128 - score: {'win': 556, 'loose': 444} 55.6 %
# Iter: 129 - score: {'win': 542, 'loose': 458} 54.2 %
# Iter: 130 - score: {'win': 563, 'loose': 437} 56.3 %
# Iter: 131 - score: {'win': 541, 'loose': 459} 54.1 %
# Iter: 132 - score: {'win': 536, 'loose': 464} 53.6 %
# Iter: 133 - score: {'win': 537, 'loose': 463} 53.7 %
# Iter: 134 - score: {'win': 533, 'loose': 467} 53.3 %
# Iter: 135 - score: {'win': 545, 'loose': 455} 54.5 %
# Iter: 136 - score: {'win': 555, 'loose': 445} 55.5 %
# Iter: 137 - score: {'win': 579, 'loose': 421} 57.9 %
# Iter: 138 - score: {'win': 549, 'loose': 451} 54.9 %
# Iter: 139 - score: {'win': 553, 'loose': 447} 55.3 %
# Iter: 140 - score: {'win': 564, 'loose': 436} 56.4 %
# Iter: 141 - score: {'win': 531, 'loose': 469} 53.1 %
# Iter: 142 - score: {'win': 561, 'loose': 439} 56.1 %
# Iter: 143 - score: {'win': 557, 'loose': 443} 55.7 %
# Iter: 144 - score: {'win': 766, 'loose': 234} 76.6 %
# Iter: 145 - score: {'win': 750, 'loose': 250} 75.0 %
# Iter: 146 - score: {'win': 785, 'loose': 215} 78.5 %
# Iter: 147 - score: {'win': 773, 'loose': 227} 77.3 %
# Iter: 148 - score: {'win': 799, 'loose': 201} 79.9 %
# Iter: 149 - score: {'win': 789, 'loose': 211} 78.9 %
# Iter: 150 - score: {'win': 769, 'loose': 231} 76.9 %
# Iter: 151 - score: {'win': 785, 'loose': 215} 78.5 %
# Iter: 152 - score: {'win': 763, 'loose': 237} 76.3 %
# Iter: 153 - score: {'win': 762, 'loose': 238} 76.2 %
# Iter: 154 - score: {'win': 776, 'loose': 224} 77.6 %
# Iter: 155 - score: {'win': 773, 'loose': 227} 77.3 %
# Iter: 156 - score: {'win': 775, 'loose': 225} 77.5 %
# Iter: 157 - score: {'win': 776, 'loose': 224} 77.6 %
# Iter: 158 - score: {'win': 787, 'loose': 213} 78.7 %
# Iter: 159 - score: {'win': 782, 'loose': 218} 78.2 %
# Iter: 160 - score: {'win': 794, 'loose': 206} 79.4 %
# Iter: 161 - score: {'win': 794, 'loose': 206} 79.4 %
# Iter: 162 - score: {'win': 766, 'loose': 234} 76.6 %
# Iter: 163 - score: {'win': 793, 'loose': 207} 79.3 %
# Iter: 164 - score: {'win': 764, 'loose': 236} 76.4 %
# Iter: 165 - score: {'win': 794, 'loose': 206} 79.4 %
# Iter: 166 - score: {'win': 775, 'loose': 225} 77.5 %
# Iter: 167 - score: {'win': 795, 'loose': 205} 79.5 %
# Iter: 168 - score: {'win': 781, 'loose': 219} 78.1 %
# Iter: 169 - score: {'win': 785, 'loose': 215} 78.5 %
# Iter: 170 - score: {'win': 793, 'loose': 207} 79.3 %
# Iter: 171 - score: {'win': 793, 'loose': 207} 79.3 %
# Iter: 172 - score: {'win': 756, 'loose': 244} 75.6 %
# Iter: 173 - score: {'win': 779, 'loose': 221} 77.9 %
# Iter: 174 - score: {'win': 788, 'loose': 212} 78.8 %
# Iter: 175 - score: {'win': 796, 'loose': 204} 79.6 %
# Iter: 176 - score: {'win': 789, 'loose': 211} 78.9 %
# Iter: 177 - score: {'win': 776, 'loose': 224} 77.6 %
# Iter: 178 - score: {'win': 769, 'loose': 231} 76.9 %
# Iter: 179 - score: {'win': 758, 'loose': 242} 75.8 %
# Iter: 180 - score: {'win': 782, 'loose': 218} 78.2 %
# Iter: 181 - score: {'win': 787, 'loose': 213} 78.7 %
# Iter: 182 - score: {'win': 776, 'loose': 224} 77.6 %
# Iter: 183 - score: {'win': 762, 'loose': 238} 76.2 %
# Iter: 184 - score: {'win': 785, 'loose': 215} 78.5 %
# Iter: 185 - score: {'win': 791, 'loose': 209} 79.1 %
# Iter: 186 - score: {'win': 775, 'loose': 225} 77.5 %
# Iter: 187 - score: {'win': 780, 'loose': 220} 78.0 %
# Iter: 188 - score: {'win': 782, 'loose': 218} 78.2 %
# Iter: 189 - score: {'win': 777, 'loose': 223} 77.7 %
# Iter: 190 - score: {'win': 787, 'loose': 213} 78.7 %
# Iter: 191 - score: {'win': 771, 'loose': 229} 77.1 %
# Iter: 192 - score: {'win': 773, 'loose': 227} 77.3 %
# Iter: 193 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 194 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 195 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 196 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 197 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 198 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 199 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 200 - score: {'win': 1000, 'loose': 0} 100.0 %
# Iter: 201 - score: {'win': 1000, 'loose': 0} 100.0 %

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.title("Porcentaje de aprendizaje en cada iteración")
plt.xlabel("Numero de iteración")
plt.ylabel("Tasa de aprendizaje")

plt.plot(range(len(historic_pct)),historic_pct)

plt.show()
